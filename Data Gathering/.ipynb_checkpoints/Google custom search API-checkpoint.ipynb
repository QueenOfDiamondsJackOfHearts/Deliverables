# %% [markdown]
# ## This notebook seeks to explore the google custom search API as a means of obtaining easily tagged data for ML purposes

# %%
#first we must download the google-api-python-client using pip
from apiclient.discovery import build
from GCS_utils import *

# %%
#now we must get the API key. Let us save this in a variable
API_key='AIzaSyChqq_YwrjPcpDqwOVc3AwdQGjrJ7yQYqI'

# %%
#here is a sample code obtained from the below URL which defines a google search and executes it
#https://stackoverflow.com/questions/37083058/programmatically-searching-google-in-python-using-custom-search
#Note that this has been slightly adapted, and is mostly to demonstrate basic fucntionality result 
#Important, a Custom Search Engine (cse) ID must be defined or error is thrown, we will use for this cell a basic
#search engine which searches the whole web.

#For search engines and other API need, we will use the google cloud console: 
#https://console.cloud.google.com/home/dashboard?project=meta-century-207318

from googleapiclient.discovery import build
import pprint

my_api_key = API_key
cse_id="014025031586105810842:wwcg6ktwacy" #all_web search engine

def google_search(search_term, api_key, cse_id, **kwargs):
    service = build("customsearch", "v1", developerKey=api_key)
    res = service.cse().list(q=search_term, cx=cse_id, **kwargs).execute()
    return res['items'] #items returns relevant metadata about the sites returned

results = google_search(
    'stackoverflow site:en.wikipedia.org', my_api_key, cse_id , num=10)
for result in results:
    type(result)
    pprint.pprint(result)
# Out:
# {'cacheId': 'SYLF4bZFF-oJ',
#  'displayLink': 'en.wikipedia.org',
#  'formattedUrl': 'https://en.wikipedia.org/wiki/Stack_Overflow',
#  'htmlFormattedUrl': 'https://en.wikipedia.org/wiki/<b>Stack_Overflow</b>',
#  'htmlSnippet': '<b>Stack Overflow</b> is a privately held website, the '
#                 'flagship site of the Stack Exchange <br>\n'
#                 'Network, created in 2008 by Jeff Atwood and Joel Spolsky. It '
#                 'was created to be&nbsp;...',
#  'htmlTitle': '<b>Stack Overflow</b> - Wikipedia',
#  'kind': 'customsearch#result',
#  'link': 'https://en.wikipedia.org/wiki/Stack_Overflow',
#  'pagemap': {'cse_image': [{'src': 'https://upload.wikimedia.org/wikipedia/en/f/fa/Stack_Overflow_homepage%2C_Feb_2017.png'}],
#              'cse_thumbnail': [{'height': '153',
#                                 'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcQkbgSLaGmvoICqsJiEwrPwpyLxwrgp7tyBGPs0E1zJO6kYZSjnyvvfXFht',
#                                 'width': '329'}],
#              'hcard': [{'bday': '2008-09-15',
#                         'category': 'Online',
#                         'fn': 'Stack Overflow',
#                         'url': 'stackoverflow.com',
#                         'url_text': 'stackoverflow.com'}],
#              'metatags': [{'og:image': 'https://upload.wikimedia.org/wikipedia/en/f/fa/Stack_Overflow_homepage%2C_Feb_2017.png',
#                            'referrer': 'origin'}]},
#  'snippet': 'Stack Overflow is a privately held website, the flagship site of '
#             'the Stack Exchange \n'
#             'Network, created in 2008 by Jeff Atwood and Joel Spolsky. It was '
#             'created to be\xa0...',
#  'title': 'Stack Overflow - Wikipedia'}
# {'cacheId': 'XLTNLo6Tlr4J',
#  'displayLink': 'en.wikipedia.org',
#  'formattedUrl': 'https://en.wikipedia.org/wiki/Stack_overflow_(disambiguation)',
#  'htmlFormattedUrl': 'https://en.wikipedia.org/wiki/<b>Stack_overflow</b>_(disambiguation)',
#  'htmlSnippet': 'A <b>stack overflow</b> is a programming error when too much '
#                 'memory is used on the <br>\n'
#                 'call stack. <b>Stack overflow</b> may also refer to: Stack '
#                 'buffer overflow, when a&nbsp;...',
#  'htmlTitle': '<b>Stack overflow</b> (disambiguation) - Wikipedia',
#  'kind': 'customsearch#result',
#  'link': 'https://en.wikipedia.org/wiki/Stack_overflow_(disambiguation)',
#  'pagemap': {'metatags': [{'referrer': 'origin'}]},
#  'snippet': 'A stack overflow is a programming error when too much memory is '
#             'used on the \n'
#             'call stack. Stack overflow may also refer to: Stack buffer '
#             'overflow, when a\xa0...',
#  'title': 'Stack overflow (disambiguation) - Wikipedia'}
# {'cacheId': 'SNkgldEPnB4J',
#  'displayLink': 'en.wikipedia.org',
#  'formattedUrl': 'https://en.wikipedia.org/wiki/Stack_buffer_overflow',
#  'htmlFormattedUrl': 'https://en.wikipedia.org/wiki/Stack_buffer_overflow',
#  'htmlSnippet': 'For other uses, see <b>Stack overflow</b> (disambiguation). '
#                 'In software, a stack buffer <br>\n'
#                 'overflow or stack buffer overrun occurs when a program writes '
#                 'to a&nbsp;...',
#  'htmlTitle': 'Stack buffer overflow - Wikipedia',
#  'kind': 'customsearch#result',
#  'link': 'https://en.wikipedia.org/wiki/Stack_buffer_overflow',
#  'pagemap': {'metatags': [{'referrer': 'origin'}]},
#  'snippet': 'For other uses, see Stack overflow (disambiguation). In software, '
#             'a stack buffer \n'
#             'overflow or stack buffer overrun occurs when a program writes to '
#             'a\xa0...',
#  'title': 'Stack buffer overflow - Wikipedia'}
# {'cacheId': 'gg3R_K1YhqQJ',
#  'displayLink': 'en.wikipedia.org',
#  'formattedUrl': 'https://en.wikipedia.org/wiki/Joel_Spolsky',
#  'htmlFormattedUrl': 'https://en.wikipedia.org/wiki/Joel_Spolsky',
#  'htmlSnippet': 'Avram Joel Spolsky (born 1965) is a software engineer and '
#                 'writer. He is the <br>\n'
#                 'author of Joel on ... Spolsky also co-founded <b>Stack '
#                 'Overflow</b>, a question and <br>\n'
#                 'answer community website for software developers, with Jeff '
#                 'Atwood. He is now <br>\n'
#                 'CEO of&nbsp;...',
#  'htmlTitle': 'Joel Spolsky - Wikipedia',
#  'kind': 'customsearch#result',
#  'link': 'https://en.wikipedia.org/wiki/Joel_Spolsky',
#  'pagemap': {'cse_image': [{'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/27/Joel_Spolsky_2014-06-18.jpg/1200px-Joel_Spolsky_2014-06-18.jpg'}],
#              'cse_thumbnail': [{'height': '224',
#                                 'src': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcQJjWlwiNR_Bmk7XGtmnu6l6Kcz5fd-Kmkd33bHe_MR6sQl7Gw4pdIZ22I',
#                                 'width': '225'}],
#              'hcard': [{'category': 'American, New Zealand, Israeli, Dual '
#                                     'citizenship[1]',
#                         'fn': 'Joel Spolsky',
#                         'role': 'Software developer CEO, Stack Exchange '
#                                 'Network Co-founder, Fog Creek Software and '
#                                 'Trello',
#                         'url': 'joelonsoftware.com',
#                         'url_text': 'joelonsoftware.com'}],
#              'metatags': [{'og:image': 'https://upload.wikimedia.org/wikipedia/commons/thumb/2/27/Joel_Spolsky_2014-06-18.jpg/1200px-Joel_Spolsky_2014-06-18.jpg',
#                            'referrer': 'origin'}],
#              'person': [{'role': 'Software developer CEO, Stack Exchange '
#                                  'Network Co-founder, Fog Creek Software and '
#                                  'Trello'}]},
#  'snippet': 'Avram Joel Spolsky (born 1965) is a software engineer and writer. '
#             'He is the \n'
#             'author of Joel on ... Spolsky also co-founded Stack Overflow, a '
#             'question and \n'
#             'answer community website for software developers, with Jeff '
#             'Atwood. He is now \n'
#             'CEO of\xa0...',
#  'title': 'Joel Spolsky - Wikipedia'}
# {'cacheId': 'GvMW2CnDL0UJ',
#  'displayLink': 'en.wikipedia.org',
#  'formattedUrl': 'https://en.wikipedia.org/wiki/Fog_Creek_Software',
#  'htmlFormattedUrl': 'https://en.wikipedia.org/wiki/Fog_Creek_Software',
#  'htmlSnippet': 'Fog Creek Software is a software company specializing in '
#                 'project management <br>\n'
#                 'tools. Its products include project management and content '
#                 'management, code <br>\n'
#                 'review tools. Contents. 1 History; 2 Products. 2.1 <b>Stack '
#                 'Overflow</b>; 2.2 Stack <br>\n'
#                 'Exchange; 2.3 Trello; 2.4 FogBugz.',
#  'htmlTitle': 'Fog Creek Software - Wikipedia',
#  'kind': 'customsearch#result',
#  'link': 'https://en.wikipedia.org/wiki/Fog_Creek_Software',
#  'pagemap': {'hcard': [{'bday': '2000',
#                         'category': 'Private',
#                         'fn': 'Fog Creek Software, Inc.',
#                         'label': 'New York, NY, USA',
#                         'url': 'fogcreek.com',
#                         'url_text': 'fogcreek.com'}],
#              'metatags': [{'referrer': 'origin'}]},
#  'snippet': 'Fog Creek Software is a software company specializing in project '
#             'management \n'
#             'tools. Its products include project management and content '
#             'management, code \n'
#             'review tools. Contents. 1 History; 2 Products. 2.1 Stack '
#             'Overflow; 2.2 Stack \n'
#             'Exchange; 2.3 Trello; 2.4 FogBugz.',
#  'title': 'Fog Creek Software - Wikipedia'}
# {'cacheId': 'D2RUPT6NKDgJ',
#  'displayLink': 'en.wikipedia.org',
#  'formattedUrl': 'https://en.wikipedia.org/wiki/Segmentation_fault',
#  'htmlFormattedUrl': 'https://en.wikipedia.org/wiki/Segmentation_fault',
#  'htmlSnippet': 'In computing, a segmentation fault (often shortened to '
#                 'segfault) or access <br>\n'
#                 'violation is a fault, .... Infinite recursion may not '
#                 'necessarily result in a <b>stack</b> <br>\n'
#                 '<b>overflow</b> depending on the language, optimizations '
#                 'performed by the compiler <br>\n'
#                 'and the exact&nbsp;...',
#  'htmlTitle': 'Segmentation fault - Wikipedia',
#  'kind': 'customsearch#result',
#  'link': 'https://en.wikipedia.org/wiki/Segmentation_fault',
#  'pagemap': {'cse_image': [{'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/d/d4/FreeBSD_kernel_panic.png/220px-FreeBSD_kernel_panic.png'}],
#              'cse_thumbnail': [{'height': '122',
#                                 'src': 'https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcQqka1eLbSmLIZLT5Uk6HQFqXqjrax8h10KTO4nw-JKKorEqtKEuIzeiA',
#                                 'width': '220'}],
#              'metatags': [{'referrer': 'origin'}]},
#  'snippet': 'In computing, a segmentation fault (often shortened to segfault) '
#             'or access \n'
#             'violation is a fault, .... Infinite recursion may not necessarily '
#             'result in a stack \n'
#             'overflow depending on the language, optimizations performed by '
#             'the compiler \n'
#             'and the exact\xa0...',
#  'title': 'Segmentation fault - Wikipedia'}
# {'cacheId': 'FaCkx9_6fiMJ',
#  'displayLink': 'en.wikipedia.org',
#  'formattedUrl': 'https://en.wikipedia.org/wiki/Stack_Exchange',
#  'htmlFormattedUrl': 'https://en.wikipedia.org/wiki/Stack_Exchange',
#  'htmlSnippet': 'Stack Exchange is a network of question-and-answer (Q&amp;A) '
#                 'websites on topics in <br>\n'
#                 'varied fields, ... In May 2010, <b>Stack Overflow</b> (as its '
#                 'own new company) raised US<br>\n'
#                 '$6 million in venture capital from Union Square Ventures and '
#                 'other investors,&nbsp;...',
#  'htmlTitle': 'Stack Exchange - Wikipedia',
#  'kind': 'customsearch#result',
#  'link': 'https://en.wikipedia.org/wiki/Stack_Exchange',
#  'pagemap': {'hcard': [{'bday': '2009-09',
#                         'category': 'Private',
#                         'fn': 'Stack Exchange Network',
#                         'label': 'New York City',
#                         'url': 'stackexchange.com',
#                         'url_text': 'stackexchange.com'}],
#              'metatags': [{'referrer': 'origin'}]},
#  'snippet': 'Stack Exchange is a network of question-and-answer (Q&A) websites '
#             'on topics in \n'
#             'varied fields, ... In May 2010, Stack Overflow (as its own new '
#             'company) raised US\n'
#             '$6 million in venture capital from Union Square Ventures and '
#             'other investors,\xa0...',
#  'title': 'Stack Exchange - Wikipedia'}
# {'cacheId': 'jW_XnFlFVLQJ',
#  'displayLink': 'en.wikipedia.org',
#  'formattedUrl': 'https://en.wikipedia.org/wiki/Buffer_overflow_protection',
#  'htmlFormattedUrl': 'https://en.wikipedia.org/wiki/Buffer_overflow_protection',
#  'htmlSnippet': 'Buffer overflow protection is any of various techniques used '
#                 'during software <br>\n'
#                 'development to enhance the security of executable programs by '
#                 'detecting buffer<br>\n'
#                 '&nbsp;...',
#  'htmlTitle': 'Buffer overflow protection - Wikipedia',
#  'kind': 'customsearch#result',
#  'link': 'https://en.wikipedia.org/wiki/Buffer_overflow_protection',
#  'pagemap': {'metatags': [{'referrer': 'origin'}]},
#  'snippet': 'Buffer overflow protection is any of various techniques used '
#             'during software \n'
#             'development to enhance the security of executable programs by '
#             'detecting buffer\n'
#             '\xa0...',
#  'title': 'Buffer overflow protection - Wikipedia'}
# {'cacheId': '91SrxPumQfcJ',
#  'displayLink': 'en.wikipedia.org',
#  'formattedUrl': 'https://en.wikipedia.org/wiki/Jeff_Atwood',
#  'htmlFormattedUrl': 'https://en.wikipedia.org/wiki/Jeff_Atwood',
#  'htmlSnippet': 'Jeff Atwood is an American software developer, author, '
#                 'blogger, and <br>\n'
#                 'entrepreneur. He writes the computer programming blog Coding '
#                 'Horror. He co-<br>\n'
#                 'founded the computer programming question-and-answer website '
#                 '<b>Stack</b> <br>\n'
#                 '<b>Overflow</b> and co-founded&nbsp;...',
#  'htmlTitle': 'Jeff Atwood - Wikipedia',
#  'kind': 'customsearch#result',
#  'link': 'https://en.wikipedia.org/wiki/Jeff_Atwood',
#  'pagemap': {'cse_image': [{'src': 'https://upload.wikimedia.org/wikipedia/commons/3/36/Long_Zheng%2C_Dan_Rigsby%2C_Jeff_Atwood_%282979598012%29.jpg'}],
#              'cse_thumbnail': [{'height': '275',
#                                 'src': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSg-Gpsf3a2XZzVtI9AR36BhiZe4b9aS1AyF9XJ2p87ynACqfwRWYIUIHT0',
#                                 'width': '183'}],
#              'hcard': [{'fn': 'Jeff Atwood',
#                         'role': 'Software developer, writer'}],
#              'metatags': [{'og:image': 'https://upload.wikimedia.org/wikipedia/commons/3/36/Long_Zheng%2C_Dan_Rigsby%2C_Jeff_Atwood_%282979598012%29.jpg',
#                            'referrer': 'origin'}],
#              'person': [{'role': 'Software developer, writer'}]},
#  'snippet': 'Jeff Atwood is an American software developer, author, blogger, '
#             'and \n'
#             'entrepreneur. He writes the computer programming blog Coding '
#             'Horror. He co-\n'
#             'founded the computer programming question-and-answer website '
#             'Stack \n'
#             'Overflow and co-founded\xa0...',
#  'title': 'Jeff Atwood - Wikipedia'}
# {'cacheId': 'UQ32LP1yKGoJ',
#  'displayLink': 'en.wikipedia.org',
#  'formattedUrl': 'https://en.wikipedia.org/wiki/File:Stack_Overflow_logo.png',
#  'htmlFormattedUrl': 'https://en.wikipedia.org/wiki/File:<b>Stack_Overflow</b>_logo.png',
#  'htmlSnippet': 'Mar 29, 2018 <b>...</b> File:<b>Stack Overflow</b> logo.svg '
#                 'is a vector version of this file. It should be ... Logo <br>\n'
#                 'der Webseite [[<b>Stack Overflow</b> (Website)|<b>Stack '
#                 'Overflow</b>]] |Quelle&nbsp;...',
#  'htmlTitle': 'File:<b>Stack Overflow</b> logo.png - Wikimedia Commons',
#  'kind': 'customsearch#result',
#  'link': 'https://en.wikipedia.org/wiki/File:Stack_Overflow_logo.png',
#  'pagemap': {'cse_image': [{'src': 'https://upload.wikimedia.org/wikipedia/commons/thumb/f/f7/Stack_Overflow_logo.png/800px-Stack_Overflow_logo.png'}],
#              'cse_thumbnail': [{'height': '115',
#                                 'src': 'https://encrypted-tbn1.gstatic.com/images?q=tbn:ANd9GcRNq24pnwi5_GJJIkuVccPpgF8j2BvY8HsoLYvjLDg6ebdiOxRH8szyV5w',
#                                 'width': '438'}],
#              'hproduct': [{'fn': 'Stack Overflow logo.png'}],
#              'metatags': [{'referrer': 'origin'}]},
#  'snippet': 'Mar 29, 2018 ... File:Stack Overflow logo.svg is a vector version '
#             'of this file. It should be ... Logo \n'
#             'der Webseite [[Stack Overflow (Website)|Stack Overflow]] '
#             '|Quelle\xa0...',
#  'title': 'File:Stack Overflow logo.png - Wikimedia Commons'}

# %%
#Now lets set up the basic script for lableing the data by directory
#The plan rn is to do use a custom search query, create a directory for that query, and put all of the 
#images we get from that into that directory so that the images we retrieve are essentially labled,
#by our query. The once this script is completed, most of the tuning will be done in the editing of the 
#search enging to give us more relevant results

import os
import requests
from apiclient.discovery import build

API_key='AIzaSyChqq_YwrjPcpDqwOVc3AwdQGjrJ7yQYqI' #should change per user

#custom search engine defined by user
#cse_id="014025031586105810842:wwcg6ktwacy" #all_web search engine
#cse_id="014025031586105810842:ut3pbkorwcq" #precipitacion_custom engine
cse_id="014025031586105810842:ut3pbkorwcq"  #non-precipitation custom engine


#root_dir='Img_LFS' #the root directory where we will put our subdirectories 
root_dir='test'

#precipitation queries
#------------------
#Query_list=['rain','snow', 'hail', 'sleet', 'precipitation', 'rainy city', 'storms', 'forecast map'] 

#non-precipitation queries
#------------------
Query_list=['sunny day -estate']#,'cloudy day -rain', 'clear night', 'clear sky', 'sunny beach', 'sunny city',
           #'beautiful day', 'beautiful night', 'cold city -snow -rain', ] 
    
#corresponds to the directories we will set up


#terms used to take advantage of the advanced search features and to ensure images are mostly real
reality= " -cartoon -graphic -animated -cgi" 


for q in Query_list:
    i=1
    #get first 100 results (limit placed by api)
    for batch in range(1,11):
        ind=i
        results=img_search(q+reality, API_key, cse_id, 10, start=ind, hq=reality)
        folder=root_dir+'/'+q
        for result in results:
            #name=q+'_'+str(i)+'.jpg'
            url=result['link']
            parsed=parse_fname(url)
            if parsed == None:
                name=q+'_'+str(i)+'.jpg' #if no name is parsed we try to save the data as a .jpg
            else:
                name=parsed
            save_img(url,folder,name)
            i=i+1
# Out:
# ------------------------------------
# no accepted format found, ensure file links to image
# https://www.gov.gg/govgg1/images/weather/d.svg

# %% [markdown]
# As of now, we have gathered the data set using this google custom search API. we are obviously limited in the amount of data we can collect. It may be better to use a better API, or try a web scraping approach.
